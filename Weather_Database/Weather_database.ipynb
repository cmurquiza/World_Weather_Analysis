# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
         cities.append(city) 
    
        

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 743

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')     
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | mar del plata
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | kodiak
# Processing Record 5 of Set 1 | port elizabeth
# Processing Record 6 of Set 1 | chokurdakh
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | moose factory
# Processing Record 11 of Set 1 | seda
# Processing Record 12 of Set 1 | ostrovnoy
# Processing Record 13 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 1 | bandarbeyla
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | bambous virieux
# Processing Record 17 of Set 1 | one hundred mile house
# City not found. Skipping...
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | ahipara
# Processing Record 20 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | olafsvik
# Processing Record 25 of Set 1 | sabla
# Processing Record 26 of Set 1 | thompson
# Processing Record 27 of Set 1 | zhezkazgan
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | arraial do cabo
# Processing Record 30 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 1 | iquitos
# Processing Record 33 of Set 1 | balotra
# Processing Record 34 of Set 1 | nokaneng
# Processing Record 35 of Set 1 | crotone
# Processing Record 36 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 1 | nikolskoye
# Processing Record 38 of Set 1 | matamoros
# Processing Record 39 of Set 1 | carnarvon
# Processing Record 40 of Set 1 | castro
# Processing Record 41 of Set 1 | podosinovets
# Processing Record 42 of Set 1 | waupun
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 1 | beeville
# Processing Record 46 of Set 1 | hovd
# Processing Record 47 of Set 1 | itarema
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | luderitz
# Processing Record 1 of Set 2 | lorengau
# Processing Record 2 of Set 2 | baruun-urt
# Processing Record 3 of Set 2 | port alfred
# Processing Record 4 of Set 2 | sur
# Processing Record 5 of Set 2 | coro
# Processing Record 6 of Set 2 | kapaa
# Processing Record 7 of Set 2 | erenhot
# Processing Record 8 of Set 2 | buraydah
# Processing Record 9 of Set 2 | new norfolk
# Processing Record 10 of Set 2 | padang
# Processing Record 11 of Set 2 | santa fe
# Processing Record 12 of Set 2 | svetlogorsk
# Processing Record 13 of Set 2 | richards bay
# Processing Record 14 of Set 2 | pisco
# Processing Record 15 of Set 2 | vagur
# Processing Record 16 of Set 2 | yumen
# Processing Record 17 of Set 2 | tomatlan
# Processing Record 18 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 2 | bethel
# Processing Record 20 of Set 2 | touros
# Processing Record 21 of Set 2 | saskylakh
# Processing Record 22 of Set 2 | altamont
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | hobyo
# Processing Record 25 of Set 2 | tera
# Processing Record 26 of Set 2 | magrath
# Processing Record 27 of Set 2 | salalah
# Processing Record 28 of Set 2 | virginia beach
# Processing Record 29 of Set 2 | hermanus
# Processing Record 30 of Set 2 | tuktoyaktuk
# Processing Record 31 of Set 2 | nome
# Processing Record 32 of Set 2 | avera
# Processing Record 33 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 2 | nagato
# Processing Record 35 of Set 2 | kahului
# Processing Record 36 of Set 2 | hofn
# Processing Record 37 of Set 2 | georgetown
# Processing Record 38 of Set 2 | oruro
# Processing Record 39 of Set 2 | saldanha
# Processing Record 40 of Set 2 | saint-philippe
# Processing Record 41 of Set 2 | chapais
# Processing Record 42 of Set 2 | barcelos
# Processing Record 43 of Set 2 | chicama
# Processing Record 44 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 2 | adrar
# Processing Record 47 of Set 2 | itoman
# Processing Record 48 of Set 2 | norman wells
# Processing Record 49 of Set 2 | yulara
# Processing Record 50 of Set 2 | khatanga
# Processing Record 1 of Set 3 | puebla
# Processing Record 2 of Set 3 | posse
# Processing Record 3 of Set 3 | torbay
# Processing Record 4 of Set 3 | ribeira grande
# Processing Record 5 of Set 3 | teruel
# Processing Record 6 of Set 3 | cabo san lucas
# Processing Record 7 of Set 3 | uray
# Processing Record 8 of Set 3 | mount gambier
# Processing Record 9 of Set 3 | victoria
# Processing Record 10 of Set 3 | ilulissat
# Processing Record 11 of Set 3 | mongar
# Processing Record 12 of Set 3 | talisay
# Processing Record 13 of Set 3 | mahebourg
# Processing Record 14 of Set 3 | asau
# Processing Record 15 of Set 3 | east london
# Processing Record 16 of Set 3 | magaria
# Processing Record 17 of Set 3 | ziarat
# Processing Record 18 of Set 3 | airai
# Processing Record 19 of Set 3 | labrea
# Processing Record 20 of Set 3 | hilo
# Processing Record 21 of Set 3 | meulaboh
# Processing Record 22 of Set 3 | dikson
# Processing Record 23 of Set 3 | poum
# Processing Record 24 of Set 3 | avarua
# Processing Record 25 of Set 3 | praya
# Processing Record 26 of Set 3 | qandala
# Processing Record 27 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 3 | hibbing
# Processing Record 29 of Set 3 | tasiilaq
# Processing Record 30 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 31 of Set 3 | sao joao da barra
# Processing Record 32 of Set 3 | ketchikan
# Processing Record 33 of Set 3 | djenne
# Processing Record 34 of Set 3 | souillac
# Processing Record 35 of Set 3 | ho
# City not found. Skipping...
# Processing Record 36 of Set 3 | yarada
# Processing Record 37 of Set 3 | faanui
# Processing Record 38 of Set 3 | senanga
# Processing Record 39 of Set 3 | bathsheba
# Processing Record 40 of Set 3 | quelimane
# Processing Record 41 of Set 3 | prince rupert
# Processing Record 42 of Set 3 | sao filipe
# Processing Record 43 of Set 3 | seguin
# Processing Record 44 of Set 3 | vuktyl
# Processing Record 45 of Set 3 | mayo
# Processing Record 46 of Set 3 | pungesti
# Processing Record 47 of Set 3 | okha
# Processing Record 48 of Set 3 | am timan
# Processing Record 49 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 3 | maniitsoq
# Processing Record 1 of Set 4 | saint-georges
# Processing Record 2 of Set 4 | la ronge
# Processing Record 3 of Set 4 | burgeo
# Processing Record 4 of Set 4 | alice springs
# Processing Record 5 of Set 4 | almaznyy
# Processing Record 6 of Set 4 | basco
# Processing Record 7 of Set 4 | katherine
# Processing Record 8 of Set 4 | beyneu
# Processing Record 9 of Set 4 | san buenaventura
# Processing Record 10 of Set 4 | eureka
# Processing Record 11 of Set 4 | alta
# Processing Record 12 of Set 4 | port blair
# Processing Record 13 of Set 4 | koslan
# Processing Record 14 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 4 | acapulco
# Processing Record 16 of Set 4 | saiha
# Processing Record 17 of Set 4 | primorsko
# Processing Record 18 of Set 4 | atuona
# Processing Record 19 of Set 4 | aklavik
# Processing Record 20 of Set 4 | hamilton
# Processing Record 21 of Set 4 | chuy
# Processing Record 22 of Set 4 | ponta do sol
# Processing Record 23 of Set 4 | saint-augustin
# Processing Record 24 of Set 4 | ondjiva
# Processing Record 25 of Set 4 | tromso
# Processing Record 26 of Set 4 | pindamonhangaba
# Processing Record 27 of Set 4 | kovdor
# Processing Record 28 of Set 4 | gao
# Processing Record 29 of Set 4 | port macquarie
# Processing Record 30 of Set 4 | palmer
# Processing Record 31 of Set 4 | mengyin
# Processing Record 32 of Set 4 | tessalit
# Processing Record 33 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 34 of Set 4 | mhlume
# Processing Record 35 of Set 4 | cedar city
# Processing Record 36 of Set 4 | mananjary
# Processing Record 37 of Set 4 | bad segeberg
# Processing Record 38 of Set 4 | sisimiut
# Processing Record 39 of Set 4 | guerrero negro
# Processing Record 40 of Set 4 | tuatapere
# Processing Record 41 of Set 4 | rocky mountain house
# Processing Record 42 of Set 4 | wanning
# Processing Record 43 of Set 4 | azul
# Processing Record 44 of Set 4 | changping
# Processing Record 45 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 4 | upernavik
# Processing Record 47 of Set 4 | birao
# Processing Record 48 of Set 4 | severo-kurilsk
# Processing Record 49 of Set 4 | gostyn
# Processing Record 50 of Set 4 | harper
# Processing Record 1 of Set 5 | saint-pierre
# Processing Record 2 of Set 5 | pevek
# Processing Record 3 of Set 5 | banyo
# Processing Record 4 of Set 5 | san patricio
# Processing Record 5 of Set 5 | manavadar
# Processing Record 6 of Set 5 | rio grande
# Processing Record 7 of Set 5 | cherskiy
# Processing Record 8 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 9 of Set 5 | areosa
# Processing Record 10 of Set 5 | ancud
# Processing Record 11 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 5 | kavieng
# Processing Record 13 of Set 5 | klaksvik
# Processing Record 14 of Set 5 | balykshi
# Processing Record 15 of Set 5 | sedelnikovo
# City not found. Skipping...
# Processing Record 16 of Set 5 | yatou
# Processing Record 17 of Set 5 | tokur
# Processing Record 18 of Set 5 | mahonda
# Processing Record 19 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 5 | tual
# Processing Record 21 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 5 | naberera
# Processing Record 23 of Set 5 | coruripe
# Processing Record 24 of Set 5 | gamba
# Processing Record 25 of Set 5 | hargeysa
# Processing Record 26 of Set 5 | tiksi
# Processing Record 27 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 5 | namatanai
# Processing Record 29 of Set 5 | nyurba
# Processing Record 30 of Set 5 | nhulunbuy
# Processing Record 31 of Set 5 | talnakh
# Processing Record 32 of Set 5 | shubarkuduk
# Processing Record 33 of Set 5 | san joaquin
# Processing Record 34 of Set 5 | cuamba
# Processing Record 35 of Set 5 | qaanaaq
# Processing Record 36 of Set 5 | sabang
# Processing Record 37 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 38 of Set 5 | denham springs
# Processing Record 39 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 5 | yenagoa
# Processing Record 41 of Set 5 | oranjestad
# Processing Record 42 of Set 5 | pipri
# Processing Record 43 of Set 5 | kloulklubed
# Processing Record 44 of Set 5 | butaritari
# Processing Record 45 of Set 5 | russell
# Processing Record 46 of Set 5 | gat
# Processing Record 47 of Set 5 | sault sainte marie
# Processing Record 48 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 5 | bud
# Processing Record 50 of Set 5 | kruisfontein
# Processing Record 1 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 2 of Set 6 | coquimbo
# Processing Record 3 of Set 6 | geraldton
# Processing Record 4 of Set 6 | baykit
# Processing Record 5 of Set 6 | terney
# Processing Record 6 of Set 6 | leningradskiy
# Processing Record 7 of Set 6 | ecoporanga
# Processing Record 8 of Set 6 | chimbote
# Processing Record 9 of Set 6 | san quintin
# Processing Record 10 of Set 6 | ulladulla
# Processing Record 11 of Set 6 | nichlaul
# Processing Record 12 of Set 6 | nalut
# Processing Record 13 of Set 6 | clyde river
# Processing Record 14 of Set 6 | treinta y tres
# Processing Record 15 of Set 6 | port-gentil
# Processing Record 16 of Set 6 | srednekolymsk
# Processing Record 17 of Set 6 | pionki
# Processing Record 18 of Set 6 | lebu
# Processing Record 19 of Set 6 | lasa
# Processing Record 20 of Set 6 | los llanos de aridane
# Processing Record 21 of Set 6 | icod de los vinos
# Processing Record 22 of Set 6 | koshki
# Processing Record 23 of Set 6 | oron
# Processing Record 24 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 6 | amapa
# Processing Record 26 of Set 6 | kribi
# Processing Record 27 of Set 6 | nanortalik
# Processing Record 28 of Set 6 | takoradi
# Processing Record 29 of Set 6 | kiruna
# Processing Record 30 of Set 6 | biak
# Processing Record 31 of Set 6 | karaton
# Processing Record 32 of Set 6 | springbok
# Processing Record 33 of Set 6 | saint george
# Processing Record 34 of Set 6 | gazi
# Processing Record 35 of Set 6 | keelung
# Processing Record 36 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 6 | ucluelet
# Processing Record 38 of Set 6 | karpenision
# City not found. Skipping...
# Processing Record 39 of Set 6 | port washington
# Processing Record 40 of Set 6 | muzhi
# Processing Record 41 of Set 6 | howard springs
# Processing Record 42 of Set 6 | wentzville
# Processing Record 43 of Set 6 | port lincoln
# Processing Record 44 of Set 6 | hasaki
# Processing Record 45 of Set 6 | mount isa
# Processing Record 46 of Set 6 | vila franca do campo
# Processing Record 47 of Set 6 | progreso
# Processing Record 48 of Set 6 | norrtalje
# Processing Record 49 of Set 6 | sainte-suzanne
# Processing Record 50 of Set 6 | hambantota
# Processing Record 1 of Set 7 | karratha
# Processing Record 2 of Set 7 | makakilo city
# Processing Record 3 of Set 7 | camacha
# Processing Record 4 of Set 7 | deputatskiy
# Processing Record 5 of Set 7 | matadi
# Processing Record 6 of Set 7 | hailar
# Processing Record 7 of Set 7 | zirandaro
# Processing Record 8 of Set 7 | barrow
# Processing Record 9 of Set 7 | miri
# Processing Record 10 of Set 7 | chaman
# Processing Record 11 of Set 7 | codrington
# Processing Record 12 of Set 7 | madang
# Processing Record 13 of Set 7 | pacific grove
# Processing Record 14 of Set 7 | khasan
# Processing Record 15 of Set 7 | ipanguacu
# Processing Record 16 of Set 7 | diamantino
# Processing Record 17 of Set 7 | marienburg
# Processing Record 18 of Set 7 | siemiatycze
# Processing Record 19 of Set 7 | laguna
# Processing Record 20 of Set 7 | hay river
# Processing Record 21 of Set 7 | la crosse
# Processing Record 22 of Set 7 | anadyr
# Processing Record 23 of Set 7 | adre
# Processing Record 24 of Set 7 | manokwari
# Processing Record 25 of Set 7 | lander
# Processing Record 26 of Set 7 | catuday
# Processing Record 27 of Set 7 | qiqihar
# Processing Record 28 of Set 7 | constitucion
# Processing Record 29 of Set 7 | maghama
# City not found. Skipping...
# Processing Record 30 of Set 7 | jamame
# Processing Record 31 of Set 7 | shimoda
# Processing Record 32 of Set 7 | sri aman
# Processing Record 33 of Set 7 | blyth
# Processing Record 34 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 7 | lokosovo
# Processing Record 36 of Set 7 | la victoria
# Processing Record 37 of Set 7 | waddan
# Processing Record 38 of Set 7 | carutapera
# Processing Record 39 of Set 7 | yuli
# Processing Record 40 of Set 7 | zyryanka
# Processing Record 41 of Set 7 | jurm
# Processing Record 42 of Set 7 | gazojak
# Processing Record 43 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 44 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 7 | batagay-alyta
# Processing Record 46 of Set 7 | neman
# Processing Record 47 of Set 7 | quang ngai
# Processing Record 48 of Set 7 | menzelinsk
# Processing Record 49 of Set 7 | uniara
# Processing Record 50 of Set 7 | poso
# Processing Record 1 of Set 8 | grindavik
# Processing Record 2 of Set 8 | bara
# Processing Record 3 of Set 8 | cidreira
# Processing Record 4 of Set 8 | beringovskiy
# Processing Record 5 of Set 8 | cap malheureux
# Processing Record 6 of Set 8 | evensk
# Processing Record 7 of Set 8 | saint anthony
# Processing Record 8 of Set 8 | kavaratti
# Processing Record 9 of Set 8 | taltal
# Processing Record 10 of Set 8 | byron bay
# Processing Record 11 of Set 8 | honiara
# Processing Record 12 of Set 8 | americus
# Processing Record 13 of Set 8 | safaqis
# City not found. Skipping...
# Processing Record 14 of Set 8 | katha
# City not found. Skipping...
# Processing Record 15 of Set 8 | nacozari
# Processing Record 16 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 17 of Set 8 | saqqez
# Processing Record 18 of Set 8 | kupang
# Processing Record 19 of Set 8 | inhambane
# Processing Record 20 of Set 8 | darhan
# Processing Record 21 of Set 8 | mayumba
# Processing Record 22 of Set 8 | vizinga
# Processing Record 23 of Set 8 | havelock
# Processing Record 24 of Set 8 | boa vista
# Processing Record 25 of Set 8 | berlevag
# Processing Record 26 of Set 8 | zalantun
# Processing Record 27 of Set 8 | paamiut
# Processing Record 28 of Set 8 | pangnirtung
# Processing Record 29 of Set 8 | dir
# Processing Record 30 of Set 8 | naze
# Processing Record 31 of Set 8 | the pas
# Processing Record 32 of Set 8 | te anau
# Processing Record 33 of Set 8 | camopi
# Processing Record 34 of Set 8 | narsaq
# Processing Record 35 of Set 8 | provideniya
# Processing Record 36 of Set 8 | igrim
# Processing Record 37 of Set 8 | sainthia
# Processing Record 38 of Set 8 | bosaso
# Processing Record 39 of Set 8 | atar
# Processing Record 40 of Set 8 | kaitangata
# Processing Record 41 of Set 8 | margate
# Processing Record 42 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 43 of Set 8 | iqaluit
# Processing Record 44 of Set 8 | rognan
# Processing Record 45 of Set 8 | la palma
# Processing Record 46 of Set 8 | batemans bay
# Processing Record 47 of Set 8 | alampur
# Processing Record 48 of Set 8 | lompoc
# Processing Record 49 of Set 8 | christchurch
# Processing Record 50 of Set 8 | juneau
# Processing Record 1 of Set 9 | xunchang
# Processing Record 2 of Set 9 | longyearbyen
# Processing Record 3 of Set 9 | qaqortoq
# Processing Record 4 of Set 9 | paka
# Processing Record 5 of Set 9 | southbridge
# Processing Record 6 of Set 9 | jarjis
# City not found. Skipping...
# Processing Record 7 of Set 9 | tall kayf
# Processing Record 8 of Set 9 | kysyl-syr
# Processing Record 9 of Set 9 | sao felix do xingu
# Processing Record 10 of Set 9 | port augusta
# Processing Record 11 of Set 9 | lebrija
# Processing Record 12 of Set 9 | santo domingo
# Processing Record 13 of Set 9 | velizh
# Processing Record 14 of Set 9 | sitka
# Processing Record 15 of Set 9 | havre-saint-pierre
# Processing Record 16 of Set 9 | bonoua
# Processing Record 17 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 18 of Set 9 | banjarmasin
# Processing Record 19 of Set 9 | vestmanna
# Processing Record 20 of Set 9 | nefteyugansk
# Processing Record 21 of Set 9 | daoukro
# Processing Record 22 of Set 9 | kamiichi
# Processing Record 23 of Set 9 | lavrentiya
# Processing Record 24 of Set 9 | west bay
# Processing Record 25 of Set 9 | dongsheng
# Processing Record 26 of Set 9 | togur
# Processing Record 27 of Set 9 | dudinka
# Processing Record 28 of Set 9 | fortuna
# Processing Record 29 of Set 9 | superior
# Processing Record 30 of Set 9 | mendahara
# City not found. Skipping...
# Processing Record 31 of Set 9 | havoysund
# Processing Record 32 of Set 9 | burnie
# Processing Record 33 of Set 9 | belmonte
# Processing Record 34 of Set 9 | tonantins
# Processing Record 35 of Set 9 | lagoa
# Processing Record 36 of Set 9 | roma
# Processing Record 37 of Set 9 | ginir
# Processing Record 38 of Set 9 | pierre
# Processing Record 39 of Set 9 | kununurra
# Processing Record 40 of Set 9 | college
# Processing Record 41 of Set 9 | hit
# Processing Record 42 of Set 9 | batagay
# Processing Record 43 of Set 9 | la sarre
# Processing Record 44 of Set 9 | mudgee
# Processing Record 45 of Set 9 | phek
# Processing Record 46 of Set 9 | muscat
# Processing Record 47 of Set 9 | gangotri
# City not found. Skipping...
# Processing Record 48 of Set 9 | tatawin
# Processing Record 49 of Set 9 | muroto
# Processing Record 50 of Set 9 | dong hoi
# Processing Record 1 of Set 10 | flinders
# Processing Record 2 of Set 10 | rock sound
# Processing Record 3 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 4 of Set 10 | tutoia
# Processing Record 5 of Set 10 | voh
# Processing Record 6 of Set 10 | moroto
# Processing Record 7 of Set 10 | krasnogorskoye
# Processing Record 8 of Set 10 | battle creek
# Processing Record 9 of Set 10 | necochea
# Processing Record 10 of Set 10 | raudeberg
# Processing Record 11 of Set 10 | san juan
# Processing Record 12 of Set 10 | mezen
# Processing Record 13 of Set 10 | luba
# Processing Record 14 of Set 10 | bolshiye klyuchishchi
# City not found. Skipping...
# Processing Record 15 of Set 10 | belaya gora
# Processing Record 16 of Set 10 | prince albert
# Processing Record 17 of Set 10 | a
# City not found. Skipping...
# Processing Record 18 of Set 10 | waingapu
# Processing Record 19 of Set 10 | vestmannaeyjar
# Processing Record 20 of Set 10 | qasigiannguit
# Processing Record 21 of Set 10 | izhma
# Processing Record 22 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 23 of Set 10 | kalmunai
# Processing Record 24 of Set 10 | jiexiu
# Processing Record 25 of Set 10 | piura
# Processing Record 26 of Set 10 | atasu
# Processing Record 27 of Set 10 | camocim
# Processing Record 28 of Set 10 | palmares do sul
# Processing Record 29 of Set 10 | bourail
# Processing Record 30 of Set 10 | mhango
# Processing Record 31 of Set 10 | hays
# Processing Record 32 of Set 10 | sheksna
# Processing Record 33 of Set 10 | jacmel
# Processing Record 34 of Set 10 | tay ninh
# Processing Record 35 of Set 10 | fergus falls
# Processing Record 36 of Set 10 | elizabeth city
# Processing Record 37 of Set 10 | carbondale
# Processing Record 38 of Set 10 | dingle
# Processing Record 39 of Set 10 | andros town
# Processing Record 40 of Set 10 | straumen
# Processing Record 41 of Set 10 | bitung
# Processing Record 42 of Set 10 | bima
# Processing Record 43 of Set 10 | hanchuan
# Processing Record 44 of Set 10 | novorzhev
# Processing Record 45 of Set 10 | mikumi
# Processing Record 46 of Set 10 | beidao
# Processing Record 47 of Set 10 | jerantut
# Processing Record 48 of Set 10 | coihaique
# Processing Record 49 of Set 10 | antofagasta
# Processing Record 50 of Set 10 | karachi
# Processing Record 1 of Set 11 | akonolinga
# Processing Record 2 of Set 11 | vallenar
# Processing Record 3 of Set 11 | benguela
# Processing Record 4 of Set 11 | teguise
# Processing Record 5 of Set 11 | bubaque
# Processing Record 6 of Set 11 | ambilobe
# Processing Record 7 of Set 11 | labytnangi
# Processing Record 8 of Set 11 | constantine
# Processing Record 9 of Set 11 | port hardy
# Processing Record 10 of Set 11 | aybak
# City not found. Skipping...
# Processing Record 11 of Set 11 | chama
# Processing Record 12 of Set 11 | pedernales
# Processing Record 13 of Set 11 | esperance
# Processing Record 14 of Set 11 | vanimo
# Processing Record 15 of Set 11 | mantua
# Processing Record 16 of Set 11 | tautira
# Processing Record 17 of Set 11 | isla mujeres
# Processing Record 18 of Set 11 | teya
# Processing Record 19 of Set 11 | merauke
# Processing Record 20 of Set 11 | iwanai
# Processing Record 21 of Set 11 | egvekinot
# Processing Record 22 of Set 11 | deer lake
# Processing Record 23 of Set 11 | bairiki
# Processing Record 24 of Set 11 | inirida
# Processing Record 25 of Set 11 | harrisonville
# Processing Record 26 of Set 11 | sungaipenuh
# Processing Record 27 of Set 11 | dale
# Processing Record 28 of Set 11 | kirakira
# Processing Record 29 of Set 11 | hihya
# Processing Record 30 of Set 11 | merritt island
# Processing Record 31 of Set 11 | santa maria
# Processing Record 32 of Set 11 | churapcha
# Processing Record 33 of Set 11 | anqing
# Processing Record 34 of Set 11 | nemuro
# Processing Record 35 of Set 11 | colares
# Processing Record 36 of Set 11 | moctezuma
# Processing Record 37 of Set 11 | vila velha
# Processing Record 38 of Set 11 | tingo maria
# Processing Record 39 of Set 11 | carroll
# Processing Record 40 of Set 11 | lafia
# Processing Record 41 of Set 11 | bonavista
# Processing Record 42 of Set 11 | emba
# Processing Record 43 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 44 of Set 11 | hualmay
# Processing Record 45 of Set 11 | sayaxche
# Processing Record 46 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 47 of Set 11 | sorland
# Processing Record 48 of Set 11 | santa cruz cabralia
# Processing Record 49 of Set 11 | riyadh
# Processing Record 50 of Set 11 | palafrugell
# Processing Record 1 of Set 12 | de aar
# Processing Record 2 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 3 of Set 12 | el alto
# Processing Record 4 of Set 12 | mandalgovi
# Processing Record 5 of Set 12 | sergeyevka
# Processing Record 6 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 12 | palana
# Processing Record 8 of Set 12 | geilo
# Processing Record 9 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 12 | edson
# Processing Record 11 of Set 12 | kashary
# Processing Record 12 of Set 12 | canto do buriti
# Processing Record 13 of Set 12 | cam pha
# City not found. Skipping...
# Processing Record 14 of Set 12 | tirumullaivasal
# Processing Record 15 of Set 12 | stornoway
# Processing Record 16 of Set 12 | puttur
# Processing Record 17 of Set 12 | vostok
# Processing Record 18 of Set 12 | corn island
# Processing Record 19 of Set 12 | ambanja
# Processing Record 20 of Set 12 | la rioja
# Processing Record 21 of Set 12 | wilmington
# Processing Record 22 of Set 12 | rosario
# Processing Record 23 of Set 12 | xining
# Processing Record 24 of Set 12 | kikwit
# Processing Record 25 of Set 12 | banjar
# Processing Record 26 of Set 12 | dehui
# Processing Record 27 of Set 12 | buncrana
# Processing Record 28 of Set 12 | clifton
# Processing Record 29 of Set 12 | pitimbu
# Processing Record 30 of Set 12 | seymchan
# Processing Record 31 of Set 12 | durango
# Processing Record 32 of Set 12 | katsuura
# Processing Record 33 of Set 12 | kargasok
# Processing Record 34 of Set 12 | gazanjyk
# Processing Record 35 of Set 12 | cavalcante
# Processing Record 36 of Set 12 | bo phloi
# Processing Record 37 of Set 12 | cascais
# Processing Record 38 of Set 12 | bulawayo
# Processing Record 39 of Set 12 | maldonado
# Processing Record 40 of Set 12 | enshi
# Processing Record 41 of Set 12 | valea mare
# Processing Record 42 of Set 12 | bilibino
# Processing Record 43 of Set 12 | san andres
# Processing Record 44 of Set 12 | safford
# Processing Record 45 of Set 12 | champerico
# Processing Record 46 of Set 12 | port keats
# Processing Record 47 of Set 12 | yaan
# Processing Record 48 of Set 12 | aluksne
# Processing Record 49 of Set 12 | ambo
# Processing Record 50 of Set 12 | puri
# Processing Record 1 of Set 13 | westpunt
# City not found. Skipping...
# Processing Record 2 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 3 of Set 13 | husavik
# Processing Record 4 of Set 13 | yurginskoye
# Processing Record 5 of Set 13 | erzincan
# Processing Record 6 of Set 13 | ngunguru
# Processing Record 7 of Set 13 | kumluca
# Processing Record 8 of Set 13 | leshukonskoye
# Processing Record 9 of Set 13 | markivka
# Processing Record 10 of Set 13 | manado
# Processing Record 11 of Set 13 | javanrud
# Processing Record 12 of Set 13 | tevaitoa
# Processing Record 13 of Set 13 | hami
# Processing Record 14 of Set 13 | monteagudo
# Processing Record 15 of Set 13 | astoria
# Processing Record 16 of Set 13 | udachnyy
# Processing Record 17 of Set 13 | algodones
# Processing Record 18 of Set 13 | warren
# Processing Record 19 of Set 13 | ajdabiya
# Processing Record 20 of Set 13 | isangel
# Processing Record 21 of Set 13 | barra patuca
# Processing Record 22 of Set 13 | scarborough
# Processing Record 23 of Set 13 | ruwi
# Processing Record 24 of Set 13 | angola
# Processing Record 25 of Set 13 | qorveh
# Processing Record 26 of Set 13 | sibu
# Processing Record 27 of Set 13 | neryungri
# Processing Record 28 of Set 13 | dunedin
# Processing Record 29 of Set 13 | upata
# Processing Record 30 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 31 of Set 13 | curillo
# Processing Record 32 of Set 13 | indramayu
# Processing Record 33 of Set 13 | tura
# Processing Record 34 of Set 13 | tiznit
# Processing Record 35 of Set 13 | itajuba
# Processing Record 36 of Set 13 | miyako
# Processing Record 37 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 38 of Set 13 | oksfjord
# Processing Record 39 of Set 13 | inuvik
# Processing Record 40 of Set 13 | brae
# Processing Record 41 of Set 13 | komsomolskiy
# Processing Record 42 of Set 13 | bengkulu
# Processing Record 43 of Set 13 | spokane
# Processing Record 44 of Set 13 | agadez
# Processing Record 45 of Set 13 | sangmelima
# Processing Record 46 of Set 13 | rockport
# Processing Record 47 of Set 13 | luganville
# Processing Record 48 of Set 13 | lubao
# Processing Record 49 of Set 13 | jackson
# Processing Record 50 of Set 13 | storforshei
# Processing Record 1 of Set 14 | buala
# Processing Record 2 of Set 14 | frankfort
# Processing Record 3 of Set 14 | kokopo
# Processing Record 4 of Set 14 | vryburg
# Processing Record 5 of Set 14 | half moon bay
# Processing Record 6 of Set 14 | diapaga
# Processing Record 7 of Set 14 | jalu
# Processing Record 8 of Set 14 | lucapa
# Processing Record 9 of Set 14 | kawalu
# Processing Record 10 of Set 14 | pahrump
# Processing Record 11 of Set 14 | ust-nera
# Processing Record 12 of Set 14 | santa catarina de tepehuanes
# Processing Record 13 of Set 14 | shelton
# Processing Record 14 of Set 14 | sinnamary
# Processing Record 15 of Set 14 | comodoro rivadavia
# Processing Record 16 of Set 14 | emerald
# Processing Record 17 of Set 14 | arlit
# Processing Record 18 of Set 14 | maneadero
# Processing Record 19 of Set 14 | sena madureira
# Processing Record 20 of Set 14 | ixtapa
# Processing Record 21 of Set 14 | bumba
# Processing Record 22 of Set 14 | elat
# Processing Record 23 of Set 14 | aswan
# Processing Record 24 of Set 14 | igarape
# Processing Record 25 of Set 14 | san vicente
# Processing Record 26 of Set 14 | san rafael
# Processing Record 27 of Set 14 | sao joao do piaui
# Processing Record 28 of Set 14 | foumban
# Processing Record 29 of Set 14 | yerbogachen
# Processing Record 30 of Set 14 | viedma
# Processing Record 31 of Set 14 | hunchun
# Processing Record 32 of Set 14 | san lorenzo
# Processing Record 33 of Set 14 | talara
# Processing Record 34 of Set 14 | okato
# Processing Record 35 of Set 14 | rab
# City not found. Skipping...
# Processing Record 36 of Set 14 | neiafu
# Processing Record 37 of Set 14 | gallup
# Processing Record 38 of Set 14 | marawi
# Processing Record 39 of Set 14 | svetlyy
# Processing Record 40 of Set 14 | ossora
# Processing Record 41 of Set 14 | majene
# Processing Record 42 of Set 14 | kapuskasing
# Processing Record 43 of Set 14 | kijang
# Processing Record 44 of Set 14 | horsham
# Processing Record 45 of Set 14 | opatija
# Processing Record 46 of Set 14 | vardo
# Processing Record 47 of Set 14 | krasnoselkup
# Processing Record 48 of Set 14 | mogadishu
# Processing Record 49 of Set 14 | broken hill
# Processing Record 50 of Set 14 | tefe
# Processing Record 1 of Set 15 | launceston
# Processing Record 2 of Set 15 | igboho
# Processing Record 3 of Set 15 | robertson
# Processing Record 4 of Set 15 | luanda
# Processing Record 5 of Set 15 | dongli
# Processing Record 6 of Set 15 | iranshahr
# Processing Record 7 of Set 15 | singaraja
# Processing Record 8 of Set 15 | faya
# Processing Record 9 of Set 15 | maumere
# Processing Record 10 of Set 15 | porto novo
# Processing Record 11 of Set 15 | phalombe
# Processing Record 12 of Set 15 | tilichiki
# Processing Record 13 of Set 15 | lianran
# Processing Record 14 of Set 15 | putyatino
# Processing Record 15 of Set 15 | baykalovo
# Processing Record 16 of Set 15 | bay roberts
# Processing Record 17 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 15 | salta
# Processing Record 19 of Set 15 | andenes
# Processing Record 20 of Set 15 | khandyga
# Processing Record 21 of Set 15 | skovde
# City not found. Skipping...
# Processing Record 22 of Set 15 | fuzhou
# Processing Record 23 of Set 15 | bondo
# Processing Record 24 of Set 15 | calvinia
# Processing Record 25 of Set 15 | harlingen
# Processing Record 26 of Set 15 | nizhniy tsasuchey
# Processing Record 27 of Set 15 | belyy yar
# Processing Record 28 of Set 15 | shelburne
# Processing Record 29 of Set 15 | carauari
# Processing Record 30 of Set 15 | russkiy aktash
# Processing Record 31 of Set 15 | goderich
# Processing Record 32 of Set 15 | picota
# Processing Record 33 of Set 15 | pangody
# Processing Record 34 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 35 of Set 15 | benito juarez
# Processing Record 36 of Set 15 | labuhan
# Processing Record 37 of Set 15 | bonito
# Processing Record 38 of Set 15 | fairbanks
# Processing Record 39 of Set 15 | dwarka
# Processing Record 40 of Set 15 | muros
# Processing Record 41 of Set 15 | tabukiniberu
# City not found. Skipping...
# Processing Record 42 of Set 15 | khuzdar
# Processing Record 43 of Set 15 | taveta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 681

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hobart -42.8794  147.3294     55.26        55          40
# 1   Mar Del Plata -38.0023  -57.5575     53.10        84           0
# 2         Mataura -46.1927  168.8643     53.87        65          98
# 3          Kodiak  57.7900 -152.4072     51.31        76         100
# 4  Port Elizabeth -33.9180   25.5701     59.31        87           0
# 5      Chokurdakh  70.6333  147.9167     24.53        84          98
# 6       Cape Town -33.9258   18.4232     56.12        87          20
# 7          Albany  42.6001  -73.9662     48.58        79         100
# 8     Yellowknife  62.4560 -114.3525     46.92        66          75
# 9   Moose Factory  51.2585  -80.6094     60.78        77         100
#
#    Wind Speed Country                 Date Current Description
# 0       12.66      AU  2022-10-04 00:51:20    scattered clouds
# 1        6.91      AR  2022-10-04 00:53:59           clear sky
# 2       10.98      NZ  2022-10-04 00:53:59     overcast clouds
# 3       10.36      US  2022-10-04 00:54:00     overcast clouds
# 4       13.80      ZA  2022-10-04 00:54:00           clear sky
# 5        4.52      RU  2022-10-04 00:54:00     overcast clouds
# 6        4.61      ZA  2022-10-04 00:49:06          few clouds
# 7        1.88      US  2022-10-04 00:49:36     overcast clouds
# 8       10.36      CA  2022-10-04 00:54:01       broken clouds
# 9        4.61      CA  2022-10-04 00:54:01     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city = city_data_df["City"]
country = city_data_df["Country"]
lats = city_data_df["Lat"]
lng = city_data_df["Lng"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]
current_description = city_data_df["Current Description"]

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hobart -42.8794  147.3294     55.26        55          40
# 1   Mar Del Plata -38.0023  -57.5575     53.10        84           0
# 2         Mataura -46.1927  168.8643     53.87        65          98
# 3          Kodiak  57.7900 -152.4072     51.31        76         100
# 4  Port Elizabeth -33.9180   25.5701     59.31        87           0
#
#    Wind Speed Country                 Date Current Description
# 0       12.66      AU  2022-10-04 00:51:20    scattered clouds
# 1        6.91      AR  2022-10-04 00:53:59           clear sky
# 2       10.98      NZ  2022-10-04 00:53:59     overcast clouds
# 3       10.36      US  2022-10-04 00:54:00     overcast clouds
# 4       13.80      ZA  2022-10-04 00:54:00           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hobart -42.8794  147.3294     55.26        55          40
# 1   Mar Del Plata -38.0023  -57.5575     53.10        84           0
# 2         Mataura -46.1927  168.8643     53.87        65          98
# 3          Kodiak  57.7900 -152.4072     51.31        76         100
# 4  Port Elizabeth -33.9180   25.5701     59.31        87           0
# 5      Chokurdakh  70.6333  147.9167     24.53        84          98
# 6       Cape Town -33.9258   18.4232     56.12        87          20
# 7          Albany  42.6001  -73.9662     48.58        79         100
# 8     Yellowknife  62.4560 -114.3525     46.92        66          75
# 9   Moose Factory  51.2585  -80.6094     60.78        77         100
#
#    Wind Speed Country                 Date Current Description
# 0       12.66      AU  2022-10-04 00:51:20    scattered clouds
# 1        6.91      AR  2022-10-04 00:53:59           clear sky
# 2       10.98      NZ  2022-10-04 00:53:59     overcast clouds
# 3       10.36      US  2022-10-04 00:54:00     overcast clouds
# 4       13.80      ZA  2022-10-04 00:54:00           clear sky
# 5        4.52      RU  2022-10-04 00:54:00     overcast clouds
# 6        4.61      ZA  2022-10-04 00:49:06          few clouds
# 7        1.88      US  2022-10-04 00:49:36     overcast clouds
# 8       10.36      CA  2022-10-04 00:54:01       broken clouds
# 9        4.61      CA  2022-10-04 00:54:01     overcast clouds

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
pd.read_csv("../Weather/WeatherPy_database.csv")
# Out:
#      City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 0          0          Hobart -42.8794  147.3294     55.26        55
# 1          1   Mar Del Plata -38.0023  -57.5575     53.10        84
# 2          2         Mataura -46.1927  168.8643     53.87        65
# 3          3          Kodiak  57.7900 -152.4072     51.31        76
# 4          4  Port Elizabeth -33.9180   25.5701     59.31        87
# ..       ...             ...      ...       ...       ...       ...
# 676      676       Fairbanks  64.8378 -147.7164     51.80        70
# 677      677          Dwarka  22.2394   68.9678     80.62        71
# 678      678           Muros  42.7762   -9.0603     59.09        89
# 679      679         Khuzdar  27.7384   66.6434     70.95        38
# 680      680          Taveta  -3.3963   37.6736     63.52        79
#
#      Cloudiness  Wind Speed Country                 Date Current Description
# 0            40       12.66      AU  2022-10-04 00:51:20    scattered clouds
# 1             0        6.91      AR  2022-10-04 00:53:59           clear sky
# 2            98       10.98      NZ  2022-10-04 00:53:59     overcast clouds
# 3           100       10.36      US  2022-10-04 00:54:00     overcast clouds
# 4             0       13.80      ZA  2022-10-04 00:54:00           clear sky
# ..          ...         ...     ...                  ...                 ...
# 676          40        5.75      US  2022-10-04 01:12:16    scattered clouds
# 677          34        6.06      IN  2022-10-04 01:12:16    scattered clouds
# 678           2        2.51      ES  2022-10-04 01:12:17           clear sky
# 679           0        2.55      PK  2022-10-04 01:12:17           clear sky
# 680          99        3.49      KE  2022-10-04 01:12:18     overcast clouds
#
# [681 rows x 11 columns]
